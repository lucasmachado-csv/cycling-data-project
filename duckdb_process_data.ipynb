# %%
import duckdb
import os
import time

# %%
DB_FILE = "cycling.duckdb"
DATA_DIR = "data"
DATA_DIR_NYC = "data_nyc"

if os.path.exists(DB_FILE):
    os.remove(DB_FILE)

# %%
con = duckdb.connect(DB_FILE)

# %%
start = time.time()

# UPDATED LINE: Added union_by_name=True
print("Ingesting data with schema union...")
con.sql(f"""
    CREATE TABLE raw_london_bike_data AS 
    SELECT * FROM read_csv('{DATA_DIR}/*.csv', union_by_name=True, filename=True)
""")

print(f"Done in {time.time() - start:.2f}s")
try:
    count = con.sql('SELECT count(*) FROM raw_london_bike_data').fetchone()[0]
    print(f"Rows: {count:,}")
except:
    print("Could not count rows.")

# con.close()
# Out:
# Ingesting data with schema union...
# Done in 10.10s
# Rows: 61,838,623

# %%
con.sql("select * from raw_london_bike_data")
# Out:
# ┌───────────┬──────────┬─────────┬──────────────────┬───────────────┬─────────────────────────────────────────────┬──────────────────┬─────────────────┬────────────────────────────────────────┬────────┬──────────────────────┬───────────────┬────────────────────┬─────────────┬─────────────┬────────────┬────────────────┬─────────────────────┬───────────────────────────────────────────────────────────────┐
# │ Rental Id │ Duration │ Bike Id │     End Date     │ EndStation Id │               EndStation Name               │    Start Date    │ StartStation Id │           StartStation Name            │ Number │ Start station number │ Start station │ End station number │ End station │ Bike number │ Bike model │ Total duration │ Total duration (ms) │                           filename                            │
# │   int64   │  int64   │  int64  │     varchar      │     int64     │                   varchar                   │     varchar      │      int64      │                varchar                 │ int64  │       varchar        │    varchar    │      varchar       │   varchar   │   varchar   │  varchar   │    varchar     │        int64        │                            varchar                            │
# ├───────────┼──────────┼─────────┼──────────────────┼───────────────┼─────────────────────────────────────────────┼──────────────────┼─────────────────┼────────────────────────────────────────┼────────┼──────────────────────┼───────────────┼────────────────────┼─────────────┼─────────────┼────────────┼────────────────┼─────────────────────┼───────────────────────────────────────────────────────────────┤
# │  73768697 │     1620 │    7457 │ 10/03/2018 12:41 │           807 │ Bevington Road West, North Kensington       │ 10/03/2018 12:14 │             647 │ Richmond Way, Shepherd's Bush          │   NULL │ NULL                 │ NULL          │ NULL               │ NULL        │ NULL        │ NULL       │ NULL           │                NULL │ data/usage-stats_100JourneyDataExtract07Mar2018-13Mar2018.csv │
# │  73703818 │      180 │   10899 │ 07/03/2018 15:14 │           446 │ York Hall, Bethnal Green                    │ 07/03/2018 15:11 │             722 │ Finnis Street, Bethnal Green           │   NULL │ NULL                 │ NULL          │ NULL               │ NULL        │ NULL        │ NULL       │ NULL           │                NULL │ data/usage-stats_100JourneyDataExtract07Mar2018-13Mar2018.csv │
# │  73729421 │     1020 │    4813 │ 08/03/2018 13:57 │           159 │ Great Marlborough Street, Soho              │ 08/03/2018 13:40 │             797 │ Ossulston Street, Somers Town          │   NULL │ NULL                 │ NULL          │ NULL               │ NULL        │ NULL        │ NULL       │ NULL           │                NULL │ data/usage-stats_100JourneyDataExtract07Mar2018-13Mar2018.csv │
# │  73749828 │      240 │    8307 │ 09/03/2018 08:57 │           578 │ Hollybush Gardens, Bethnal Green            │ 09/03/2018 08:53 │             719 │ Victoria Park Road, Hackney Central    │   NULL │ NULL                 │ NULL          │ NULL               │ NULL        │ NULL        │ NULL       │ NULL           │                NULL │ data/usage-stats_100JourneyDataExtract07Mar2018-13Mar2018.csv │
# │  73822143 │      240 │    8433 │ 13/03/2018 07:00 │           578 │ Hollybush Gardens, Bethnal Green            │ 13/03/2018 06:56 │             719 │ Victoria Park Road, Hackney Central    │   NULL │ NULL                 │ NULL          │ NULL               │ NULL        │ NULL        │ NULL       │ NULL           │                NULL │ data/usage-stats_100JourneyDataExtract07Mar2018-13Mar2018.csv │
# │  73838548 │      240 │    2879 │ 13/03/2018 16:38 │           107 │ Finsbury Leisure Centre, St. Luke's         │ 13/03/2018 16:34 │             326 │ Graham Street, Angel                   │   NULL │ NULL                 │ NULL          │ NULL               │ NULL        │ NULL        │ NULL       │ NULL           │                NULL │ data/usage-stats_100JourneyDataExtract07Mar2018-13Mar2018.csv │
# │  73833603 │      180 │    2180 │ 13/03/2018 12:20 │           446 │ York Hall, Bethnal Green                    │ 13/03/2018 12:17 │             719 │ Victoria Park Road, Hackney Central    │   NULL │ NULL                 │ NULL          │ NULL               │ NULL        │ NULL        │ NULL       │ NULL           │                NULL │ data/usage-stats_100JourneyDataExtract07Mar2018-13Mar2018.csv │
# │  
────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                                                                                                                                           19 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
columns = [row[0] for row in con.sql("DESCRIBE raw_london_bike_data").fetchall()]
columns
# Out:
# ['Rental Id',
#  'Duration',
#  'Bike Id',
#  'End Date',
#  'EndStation Id',
#  'EndStation Name',
#  'Start Date',
#  'StartStation Id',
#  'StartStation Name',
#  'Number',
#  'Start station number',
#  'Start station',
#  'End station number',
#  'End station',
#  'Bike number',
#  'Bike model',
#  'Total duration',
#  'Total duration (ms)',
#  'filename']

# %%
def safe_col(col_name):
    """Returns the column name in double quotes if it exists, else NULL"""
    if col_name in columns:
        return f'"{col_name}"'
    return "NULL"


sql_transform = f"""
    DROP TABLE IF EXISTS london_bike_data;
    CREATE TABLE london_bike_data AS
    SELECT
        COALESCE(CAST({safe_col('Number')} AS VARCHAR), CAST({safe_col('Rental Id')} AS VARCHAR)) AS rental_id,
        
        COALESCE(
            -- Try UK format (DD/MM/YYYY HH:MM)
            try_strptime({safe_col('Start date')}, '%d/%m/%Y %H:%M'),
            try_strptime({safe_col('Start Date')}, '%d/%m/%Y %H:%M'),
            
            -- Try ISO format (YYYY-MM-DD HH:MM)
            try_strptime({safe_col('Start date')}, '%Y-%m-%d %H:%M'),
            try_strptime({safe_col('Start Date')}, '%Y-%m-%d %H:%M'),
            
            -- Fallback to generic timestamp cast (handles strict ISO with seconds)
            TRY_CAST({safe_col('Start date')} AS TIMESTAMP), 
            TRY_CAST({safe_col('Start Date')} AS TIMESTAMP)
        ) AS start_date,
        
        COALESCE(
            -- Try UK format
            try_strptime({safe_col('End date')}, '%d/%m/%Y %H:%M'),
            try_strptime({safe_col('End Date')}, '%d/%m/%Y %H:%M'),
            
            -- Try ISO format
            try_strptime({safe_col('End date')}, '%Y-%m-%d %H:%M'),
            try_strptime({safe_col('End Date')}, '%Y-%m-%d %H:%M'),
            
            -- Fallback
            TRY_CAST({safe_col('End date')} AS TIMESTAMP), 
            TRY_CAST({safe_col('End Date')} AS TIMESTAMP)
        ) AS end_date,
        
        COALESCE(
            CAST({safe_col('Total duration (ms)')} AS DOUBLE)/1000.0, 
            CAST({safe_col('Total duration')} AS DOUBLE), 
            CAST({safe_col('Duration')} AS DOUBLE)
        ) AS duration_seconds,
        
        COALESCE(CAST({safe_col('Bike number')} AS VARCHAR), CAST({safe_col('Bike Id')} AS VARCHAR)) AS bike_id,
        
        -- FIX: Cast Station IDs to VARCHAR
        COALESCE(CAST({safe_col('Start station number')} AS VARCHAR), CAST({safe_col('StartStation Id')} AS VARCHAR)) AS start_station_id,
        COALESCE({safe_col('Start station')}, {safe_col('StartStation Name')}) AS start_station_name,
        
        -- FIX: Cast Station IDs to VARCHAR
        COALESCE(CAST({safe_col('End station number')} AS VARCHAR), CAST({safe_col('EndStation Id')} AS VARCHAR)) AS end_station_id,
        COALESCE({safe_col('End station')}, {safe_col('EndStation Name')}) AS end_station_name,
        
        {safe_col('Bike model')} AS bike_model,
        filename
    FROM raw_london_bike_data
    WHERE start_date IS NOT NULL
        AND end_date IS NOT NULL
        AND duration_seconds > 0
        AND duration_seconds <= 1000 * 60  -- keep rides <= 1000 minutes
"""

con.sql(sql_transform)

# %%
con.sql("SELECT * FROM london_bike_data ORDER BY start_date DESC")
# Out:
# ┌───────────┬─────────────────────┬─────────────────────┬──────────────────┬─────────┬──────────────────┬────────────────────────────────────────────┬────────────────┬────────────────────────────────────────┬────────────┬───────────────────────────────────────────────────────────────┐
# │ rental_id │     start_date      │      end_date       │ duration_seconds │ bike_id │ start_station_id │             start_station_name             │ end_station_id │            end_station_name            │ bike_model │                           filename                            │
# │  varchar  │      timestamp      │      timestamp      │      double      │ varchar │     varchar      │                  varchar                   │    varchar     │                varchar                 │  varchar   │                            varchar                            │
# ├───────────┼─────────────────────┼─────────────────────┼──────────────────┼─────────┼──────────────────┼────────────────────────────────────────────┼────────────────┼────────────────────────────────────────┼────────────┼───────────────────────────────────────────────────────────────┤
# │ 136450330 │ 2023-12-31 23:59:00 │ 2024-01-01 00:12:00 │          771.575 │ 58456   │ 001220           │ Imperial College, Knightsbridge            │ 003464         │ Green Street, Mayfair                  │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136450329 │ 2023-12-31 23:59:00 │ 2024-01-01 00:16:00 │         1023.305 │ 52107   │ 001196           │ Vincent Square, Westminster                │ 001196         │ Vincent Square, Westminster            │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136450328 │ 2023-12-31 23:59:00 │ 2024-01-01 00:50:00 │         3071.423 │ 30722   │ 200094           │ St. Bride Street, Holborn                  │ 001135         │ Claverton Street, Pimlico              │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136450331 │ 2023-12-31 23:59:00 │ 2024-01-01 00:32:00 │         1945.176 │ 50838   │ 000964           │ Bath Street, St. Luke's                    │ 003437         │ Curzon Street, Mayfair                 │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136450327 │ 2023-12-31 23:59:00 │ 2024-01-01 00:19:00 │         1206.838 │ 17711   │ 003433           │ Sadlers Sports Centre, Finsbury            │ 003433         │ Sadlers Sports Centre, Finsbury        │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136450325 │ 2023-12-31 23:58:00 │ 2024-01-01 00:27:00 │         1784.383 │ 35491   │ 003451           │ Golden Square, Soho                        │ 001116         │ Emperor's Gate, South Kensington       │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136450326 │ 2023-12-31 23:58:00 │ 2024-01-01 00:03:00 │          283.652 │ 54006   │ 200250           │ Cleveland Way, Stepney                     │ 001105         │ LMU Commercial Road, Whitechapel       │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136450319 │ 2023-12-31 23:57:00 │ 2024-01-01 00:21:00 │         1431.463 │ 56745   │ 001095           │ LSBU (Borough Road), Elephant & Castle     │ 001095         │ LSBU (Borough Road), Elephant & Castle │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136450322 │ 2023-12-31 23:57:00 │ 2024-01-01 00:18:00 │         1242.687 │ 54458   │ 001122           │ Ashley Place, Victoria                     │ 200178         │ Buckingham Gate, Westminster           │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136450324 │ 2023-12-31 23:57:00 │ 2024-01-01 00:14:00 │         1021.915 │ 40122   │ 001161           │ Brushfield Street, Liverpool Street        │ 001161         │ Brushfield Street, Liverpool Street    │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │     ·     │          ·          │          ·          │             ·    │   ·     │   ·              │               ·                            │   ·            │            ·                           │    ·       │                               ·                               │
# │     ·     │          ·          │          ·          │             ·    │   ·     │   ·              │               ·                            │   ·            │            ·                           │    ·       │                               ·                               │
# │     ·     │          ·          │          ·          │             ·    │   ·     │   ·              │               ·                            │   ·            │            ·                           │    ·       │                               ·                               │
# │ 136440069 │ 2023-12-30 18:34:00 │ 2023-12-30 18:50:00 │          986.538 │ 59651   │ 001090           │ Warren Street Station, Euston              │ 001029         │ Windsor Terrace, Hoxton                │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136440070 │ 2023-12-30 18:34:00 │ 2023-12-30 18:34:00 │            8.014 │ 54811   │ 001205           │ Black Prince Road, Vauxhall                │ 001205         │ Black Prince Road, Vauxhall            │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136440071 │ 2023-12-30 18:34:00 │ 2023-12-30 18:50:00 │          921.162 │ 60426   │ 300200           │ East Village, Queen Elizabeth Olympic Park │ 200057         │ Belford House, Haggerston              │ PBSC_EBIKE │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136440072 │ 2023-12-30 18:34:00 │ 2023-12-30 18:45:00 │          663.735 │ 54749   │ 001090           │ Warren Street Station, Euston              │ 200026         │ Greenland Road, Camden Town            │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136440073 │ 2023-12-30 18:34:00 │ 2023-12-30 18:54:00 │         1174.928 │ 59469   │ 200152           │ Pitfield Street North,Hoxton               │ 001052         │ Soho Square , Soho                     │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136440065 │ 2023-12-30 18:34:00 │ 2023-12-30 18:53:00 │         1140.555 │ 57067   │ 002683           │ Millbank Tower, Pimlico                    │ 000994         │ Tanner Street, Bermondsey              │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136440066 │ 2023-12-30 18:34:00 │ 2023-12-30 18:55:00 │         1301.617 │ 30586   │ 001163           │ Wardour Street, Soho                       │ 200248         │ Pitfield Street Central, Hoxton        │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136440067 │ 2023-12-30 18:34:00 │ 2023-12-30 18:42:00 │          483.215 │ 61149   │ 200250           │ Cleveland Way, Stepney                     │ 200159         │ Goldsmith's Row, Haggerston            │ PBSC_EBIKE │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136440062 │ 2023-12-30 18:33:00 │ 2023-12-30 18:44:00 │          654.085 │ 54496   │ 300014           │ Falcon Road, Clapham Junction              │ 200001         │ Limerston Street, West Chelsea         │ CLASSIC    │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# │ 136440063 │ 2023-12-30 18:33:00 │ 2023-12-30 19:01:00 │         1675.605 │ 60539   │ 001079           │ Endsleigh Gardens, Euston                  │ 200123         │ Burdett Road, Mile End                 │ PBSC_EBIKE │ data/usage-stats_386JourneyDataExtract15Dec2023-31Dec2023.csv │
# ├───────────┴─────────────────────┴─────────────────────┴──────────────────┴─────────┴──────────────────┴────────────────────────────────────────────┴────────────────┴────────────────────────────────────────┴────────────┴───────────────────────────────────────────────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                  11 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# # NYC Data Import

# %%
con.sql(f"""
    CREATE TABLE raw_nyc_bike_data AS 
    SELECT * FROM read_csv('{DATA_DIR_NYC}/**/*.csv', union_by_name=True, filename=True)
""")

# %%
con.sql("SELECT * FROM raw_nyc_bike_data")
# Out:
# ┌──────────────┬─────────────────────────┬─────────────────────────┬──────────────────┬─────────────────────┬────────────────────────┬─────────────────────────┬────────────────┬────────────────────────────┬──────────────────────┬───────────────────────┬────────┬────────────┬────────────┬────────┬─────────┬───────────────┬────────────┬───────────┬────────────────────┬──────────────────┬──────────────────┬────────────────┬───────────┬───────────┬─────────┬─────────┬───────────────┬──────────────────────────────────────────────────────────────┐
────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        29 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
columns = [row[0] for row in con.sql("DESCRIBE raw_nyc_bike_data").fetchall()]
print(f"Staging columns detected: {len(columns)}")

def safe_col(col_name):
    return f'"{col_name}"' if col_name in columns else "NULL"

# 2. Transform & Unify
# Mapping Old Schema -> New Schema
print("Step 2: Creating unified 'nyc_biking_data' table...")

sql_transform = f"""
    CREATE OR REPLACE TABLE nyc_biking_data AS
    SELECT
        -- ID: New data has ride_id, Old data doesn't (we can use filename/row or NULL)
        {safe_col('ride_id')} AS ride_id,
        
        -- Dates: 'started_at' (New) vs 'starttime' (Old)
        COALESCE(
            TRY_CAST({safe_col('started_at')} AS TIMESTAMP), 
            TRY_CAST({safe_col('starttime')} AS TIMESTAMP)
        ) AS start_time,
        
        COALESCE(
            TRY_CAST({safe_col('ended_at')} AS TIMESTAMP), 
            TRY_CAST({safe_col('stoptime')} AS TIMESTAMP)
        ) AS end_time,
        
        -- Stations: 'start_station_id' (New) vs 'start station id' (Old)
        COALESCE(CAST({safe_col('start_station_id')} AS VARCHAR), CAST({safe_col('start station id')} AS VARCHAR)) AS start_station_id,
        COALESCE({safe_col('start_station_name')}, {safe_col('start station name')}) AS start_station_name,
        
        COALESCE(CAST({safe_col('end_station_id')} AS VARCHAR), CAST({safe_col('end station id')} AS VARCHAR)) AS end_station_id,
        COALESCE({safe_col('end_station_name')}, {safe_col('end station name')}) AS end_station_name,
        
        -- Lat/Lng: Only reliable in New data, Old data has it too usually
        COALESCE(CAST({safe_col('start_lat')} AS DOUBLE), CAST({safe_col('start station latitude')} AS DOUBLE)) AS start_lat,
        COALESCE(CAST({safe_col('start_lng')} AS DOUBLE), CAST({safe_col('start station longitude')} AS DOUBLE)) AS start_lng,
        
        COALESCE(CAST({safe_col('end_lat')} AS DOUBLE), CAST({safe_col('end station latitude')} AS DOUBLE)) AS end_lat,
        COALESCE(CAST({safe_col('end_lng')} AS DOUBLE), CAST({safe_col('end station longitude')} AS DOUBLE)) AS end_lng,

        -- Member Type: 'member_casual' (New: member/casual) vs 'usertype' (Old: Subscriber/Customer)
        COALESCE({safe_col('member_casual')}, CASE WHEN {safe_col('usertype')} = 'Subscriber' THEN 'member' ELSE 'casual' END) AS user_type,
        
        filename
    FROM raw_nyc_bike_data
    WHERE start_time IS NOT NULL
        AND end_time IS NOT NULL
        AND date_diff('second', start_time, end_time) > 0
        AND date_diff('second', start_time, end_time) <= 1000 * 60  -- keep rides <= 1000 minutes
"""

con.sql(sql_transform)

# 3. Validation
count = con.sql("SELECT count(*) FROM nyc_biking_data").fetchone()[0]
print(f"Step 3: Done. Total NYC Rows: {count:,}")
# Out:
# Staging columns detected: 29
# Step 2: Creating unified 'nyc_biking_data' table...
# Step 3: Done. Total NYC Rows: 150,892,056

# %%
con.sql("SELECT * FROM nyc_biking_data")
# Out:
# ┌─────────┬─────────────────────────┬─────────────────────────┬──────────────────┬─────────────────────┬────────────────┬──────────────────────────────┬─────────────┬──────────────┬───────────────────┬───────────────────┬───────────┬──────────────────────────────────────────────────────────────┐
│ member    │ data_nyc/2018-citibike-tripdata/201801-citibike-tripdata.csv │
# │ NULL    │ 2018-01-29 23:47:54.387 │ 2018-01-29 23:53:44.938 │ 144              │ Nassau St & Navy St │ 419            │ Carlton Ave & Park Ave       │ 40.69839895 │ -73.98068914 │       40.69580705 │      -73.97355569 │ member    │ data_nyc/2018-citibike-tripdata/201801-citibike-tripdata.csv │
# │ NULL    │ 2018-01-30 08:25:46.736 │ 2018-01-30 08:42:03.106 │ 144              │ Nassau St & Navy St │ 3576           │ Park Pl & Vanderbilt Ave     │ 40.69839895 │ -73.98068914 │           40.6767 │        -73.969024 │ member    │ data_nyc/2018-citibike-tripdata/201801-citibike-tripdata.csv │
# │ NULL    │ 2018-01-30 09:54:48.395 │ 2018-01-30 09:59:06.814 │ 144              │ Nassau St & Navy St │ 245            │ Myrtle Ave & St Edwards St   │ 40.69839895 │ -73.98068914 │       40.69327018 │      -73.97703874 │ member    │ data_nyc/2018-citibike-tripdata/201801-citibike-tripdata.csv │
# │ NULL    │ 2018-01-30 12:07:21.395 │ 2018-01-30 12:25:28.41  │ 144              │ Nassau St & Navy St │ 377            │ 6 Ave & Canal St             │ 40.69839895 │ -73.98068914 │       40.72243797 │      -74.00566443 │ member    │ data_nyc/2018-citibike-tripdata/201801-citibike-tripdata.csv │
# │ NULL    │ 2018-01-30 16:32:50.609 │ 2018-01-30 16:38:13.278 │ 144              │ Nassau St & Navy St │ 239            │ Willoughby St & Fleet St     │ 40.69839895 │ -73.98068914 │       40.69196566 │       -73.9813018 │ member    │ data_nyc/2018-citibike-tripdata/201801-citibike-tripdata.csv │
# │ NULL    │ 2018-01-30 17:13:28.899 │ 2018-01-30 17:43:09.625 │ 144              │ Nassau St & Navy St │ 223            │ W 13 St & 7 Ave              │ 40.69839895 │ -73.98068914 │       40.73781509 │      -73.99994661 │ member    │ data_nyc/2018-citibike-tripdata/201801-citibike-tripdata.csv │
# │ NULL    │ 2018-01-30 18:22:12.62  │ 2018-01-30 18:23:34.726 │ 144              │ Nassau St & Navy St │ 144            │ Nassau St & Navy St          │ 40.69839895 │ -73.98068914 │       40.69839895 │      -73.98068914 │ member    │ data_nyc/2018-citibike-tripdata/201801-citibike-tripdata.csv │
# │ NULL    │ 2018-01-30 18:24:00.331 │ 2018-01-30 18:28:39.085 │ 144              │ Nassau St & Navy St │ 239            │ Willoughby St & Fleet St     │ 40.69839895 │ -73.98068914 │       40.69196566 │       -73.9813018 │ member    │ data_nyc/2018-citibike-tripdata/201801-citibike-tripdata.csv │
# │ NULL    │ 2018-01-30 19:26:22.969 │ 2018-01-30 19:45:45.576 │ 144              │ Nassau St & Navy St │ 3580           │ St Johns Pl & Washington Ave │ 40.69839895 │ -73.98068914 │        40.6737236 │       -73.9631611 │ member    │ data_nyc/2018-citibike-tripdata/201801-citibike-tripdata.csv │
# ├─────────┴─────────────────────────┴─────────────────────────┴──────────────────┴─────────────────────┴────────────────┴──────────────────────────────┴─────────────┴──────────────┴───────────────────┴───────────────────┴───────────┴──────────────────────────────────────────────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                             13 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# # Combined Dataset

# %%
sql_transform = f"""
CREATE OR REPLACE TABLE joint_bike_data AS
SELECT
    start_date    AS start_time,
    end_date      AS end_time,
    duration_seconds AS duration_seconds,
    'London'      AS city
FROM london_bike_data

UNION ALL

SELECT
    start_time,
    end_time,
    date_diff('second', start_time, end_time) AS duration_seconds,
    'NYC' AS city
FROM nyc_biking_data
"""

con.sql(sql_transform)

# %%
con.sql("SELECT * FROM joint_bike_data")
# Out:
# ┌─────────────────────┬─────────────────────┬──────────────────┬─────────┐
# │     start_time      │      end_time       │ duration_seconds │  city   │
# │      timestamp      │      timestamp      │      double      │ varchar │
# ├─────────────────────┼─────────────────────┼──────────────────┼─────────┤
# │ 2018-03-10 12:14:00 │ 2018-03-10 12:41:00 │           1620.0 │ London  │
# │ 2018-03-07 15:11:00 │ 2018-03-07 15:14:00 │            180.0 │ London  │
# │ 2018-03-08 13:40:00 │ 2018-03-08 13:57:00 │           1020.0 │ London  │
# │ 2018-03-09 08:53:00 │ 2018-03-09 08:57:00 │            240.0 │ London  │
# │ 2018-03-13 06:56:00 │ 2018-03-13 07:00:00 │            240.0 │ London  │
# │ 2018-03-13 16:34:00 │ 2018-03-13 16:38:00 │            240.0 │ London  │
# │ 2018-03-13 12:17:00 │ 2018-03-13 12:20:00 │            180.0 │ London  │
# │ 2018-03-13 09:07:00 │ 2018-03-13 09:11:00 │            240.0 │ London  │
# │ 2018-03-13 20:29:00 │ 2018-03-13 20:38:00 │            540.0 │ London  │
# │ 2018-03-10 15:08:00 │ 2018-03-10 15:40:00 │           1920.0 │ London  │
# │          ·          │          ·          │              ·   │   ·     │
# │          ·          │          ·          │              ·   │   ·     │
# │          ·          │          ·          │              ·   │   ·     │
# │ 2018-03-07 14:53:00 │ 2018-03-07 15:01:00 │            480.0 │ London  │
# │ 2018-03-10 06:01:00 │ 2018-03-10 06:11:00 │            600.0 │ London  │
# │ 2018-03-08 14:43:00 │ 2018-03-08 15:00:00 │           1020.0 │ London  │
# │ 2018-03-12 21:00:00 │ 2018-03-12 21:22:00 │           1320.0 │ London  │
# │ 2018-03-11 13:59:00 │ 2018-03-11 14:07:00 │            480.0 │ London  │
# │ 2018-03-08 08:36:00 │ 2018-03-08 08:44:00 │            480.0 │ London  │
# │ 2018-03-13 17:38:00 │ 2018-03-13 17:47:00 │            540.0 │ London  │
# │ 2018-03-11 10:44:00 │ 2018-03-11 10:50:00 │            360.0 │ London  │
# │ 2018-03-12 09:04:00 │ 2018-03-12 09:17:00 │            780.0 │ London  │
# │ 2018-03-07 14:06:00 │ 2018-03-07 14:20:00 │            840.0 │ London  │
# ├─────────────────────┴─────────────────────┴──────────────────┴─────────┤
# │ ? rows (>9999 rows, 20 shown)                                4 columns │
# └────────────────────────────────────────────────────────────────────────┘

# %%
con.close()

# %% [markdown]
# # Build Data Layer

# %%
# Load the extension
# %load_ext sql

# Connect to your existing database
# %sql duckdb:///cycling.duckdb

# %%
# %%sql
# SHOW TABLES

# %%
# %%sql
# SELECT * FROM london_bike_data

# %%
# %%sql
# DROP TABLE IF EXISTS london_bike_data_daily;
# CREATE TABLE london_bike_data_daily AS (
# SELECT
# date_trunc('month', start_date) AS start_month,
# date_trunc('month', end_date) AS end_month,
# # bike_id,
# start_station_id,
# start_station_name,
# end_station_id,
# end_station_name,
# bike_model,
# COUNT(*) AS count,
# SUM(duration_seconds) AS total_duration_seconds,
# AVG(duration_seconds) AS avg_duration_seconds,
# MAX(duration_seconds) AS max_duration_seconds,
# MIN(duration_seconds) AS min_duration_seconds,
# STDDEV(duration_seconds) AS std_duration_seconds
# FROM london_bike_data
# GROUP BY 1,2,3,4,5,6,7);
#
# SELECT * FROM london_bike_data_daily;

# %%
# %%sql
# SELECT COUNT(*) FROM london_bike_data_summary;

# %%
# %sql --close duckdb:///cycling.duckdb
